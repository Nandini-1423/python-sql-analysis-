# %%
#pip install kaggle
#!pip install opendatasets

# %%
import opendatasets as od
#import kaggle

# %% [raw]
# # here are the process for uploading a dataset from kaggle to jupyter notebook
# 1. first install opendatsasets  #!pip install opendatasets
# 2. import opendatasets as od
# 3. dataset = 'https://www.kaggle.com/datasets/ankitbansal06/retail-orders'  "here add the kaggle dataset link direct , which you want to add "
# 4. od.download(dataset) to download the dataset

# %%
dataset = 'https://www.kaggle.com/datasets/ankitbansal06/retail-orders'

# %%
od.download(dataset)
# Out:
# Skipping, found downloaded files in ".\retail-orders" (use force=True to force download)

# %%
import os

# Set the directory path
directory = './retail-orders'

# List all files in the directory
files = os.listdir(directory)
print(files)
# Out:
# ['orders.csv']

# %% [markdown]
# # project start

# %%
import pandas as pd
df = pd.read_csv('orders.csv',na_values=['Not Available','unknown'])
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
#rename column ..make them lower case and replace sapace with underscore
df.rename(columns={'Order Id':'order_id','City':'city'})
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')
df.head(5)
#data.dtypes
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %% [markdown]
# # derive new columns discount , sale price and profit

# %%
df.dtypes
# Out:
# order_id             int64
# order_date          object
# ship_mode           object
# segment             object
# country             object
# city                object
# state               object
# postal_code          int64
# region              object
# category            object
# sub_category        object
# product_id          object
# cost_price           int64
# list_price           int64
# quantity             int64
# discount_percent     int64
# dtype: object

# %%
# 1. column of discount (list price * discount percent)
df['discount']=df['list_price']*df['discount_percent']*.01 

df.head()
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1  2023-03-01    Second Class   Consumer  United States
# 1         2  2023-08-15    Second Class   Consumer  United States
# 2         3  2023-01-10    Second Class  Corporate  United States
# 3         4  2022-06-18  Standard Class   Consumer  United States
# 4         5  2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   sub_category       product_id  cost_price  list_price  quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
#2 . column of sale_price (list price - discount percent)
df['sale_price'] =df['list_price']-df['discount']
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
# 3 . column of profit (sale price - cost_price)
df['profit'] =df['sale_price']-df['cost_price']
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
  #convert order date from object data type to datetime
df.dtypes
# Out:
# order_id              int64
# order_date           object
# ship_mode            object
# segment              object
# country              object
# city                 object
# state                object
# postal_code           int64
# region               object
# category             object
# sub_category         object
# product_id           object
# cost_price            int64
# list_price            int64
# quantity              int64
# discount_percent      int64
# discount            float64
# sale_price          float64
# profit              float64
# dtype: object

# %%
#you can see all the datatypes of date in the form of object , now you have to change it in date
pd.to_datetime(df['order_date'],format="%Y-%m-%d")
# Out:
# 0      2023-03-01
# 1      2023-08-15
# 2      2023-01-10
# 3      2022-06-18
# 4      2022-07-13
#           ...
# 9989   2023-02-18
# 9990   2023-03-17
# 9991   2022-08-07
# 9992   2022-11-19
# 9993   2022-07-17
# Name: order_date, Length: 9994, dtype: datetime64[ns]

# %%
# you can drop cost price, list price and discount percent columns , bcz this is not needed 
df.drop(columns=['cost_price','list_price','discount_percent'] ,inplace=True)

# %%
df.dtypes  # now you can see that these columns are permanenty delete
# Out:
# order_id          int64
# order_date       object
# ship_mode        object
# segment          object
# country          object
# city             object
# state            object
# postal_code       int64
# region           object
# category         object
# sub_category     object
# product_id       object
# quantity          int64
# discount        float64
# sale_price      float64
# profit          float64
# dtype: object

# %% [markdown]
# # load the data into sql server using replace option

# %%
# importing libraries 
import pandas as pd
import sqlalchemy as sal  #used to connect to sql server 
engine = sal.create_engine('mssql://NANDINI\SQLEXPRESS/master?driver=ODBC+DRIVER+17+FOR+SQL+SERVER')
conn=engine.connect()  # here mssql is the workolace, nandini\sqlexpress is the server name , and  after is the odbc driver source administration -user data sources

# %%
#load the data into sql server using append option
#df.to_sql('df_orders',con = conn , index=False, if_exists ='append')



df.to_sql('df_orders', con=conn, index=False, if_exists='replace')  # This will replace the entire table.  
# or  
#df.to_sql('df_orders', con=conn, index=False, if_exists='fail')  # This will raise an error if the table already exists.
# Out:
# 38
